# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install mlxtend
# !pip cache purge

# %%
from mlxtend.plotting import plot_decision_regions

# %%
from sklearn.datasets import make_circles, make_moons

# %%
# X, y = make_circles(n_samples=100, noise=0.2, factor=0.2, random_state=666)
X, y = make_moons(n_samples=100, noise=0.05, random_state=666)

# %%
X[:5]
# Out:
# array([[ 1.71657517,  0.17895829],
#        [ 0.0121074 ,  0.26198486],
#        [-0.59521354,  0.79762636],
#        [-0.75813546,  0.72093634],
#        [-0.91067555,  0.42330777]])

# %%
y[:5]
# Out:
# array([1, 1, 0, 0, 0], dtype=int64)

# %%
plt.scatter(X[y==0, 0], X[y==0, 1], c='r')
plt.scatter(X[y==1, 0], X[y==1, 1], c='b')
plt.show()

# %%
plt.scatter(X[y==0,0],X[y==0,1],c='r')
plt.scatter(X[y==1,0],X[y==1,1],c='r')
plt.show()

# %%
plot_decision_regions(X,y,logistic)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plot_decision_regions(X,y,logistic)
#       2 plt.show()
#
# NameError: name 'logistic' is not defined
